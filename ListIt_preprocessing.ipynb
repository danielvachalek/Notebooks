# %%
# !pip install pandas
# !pip install xlrd
# !pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# ...
#      |████████████████████████████████| 243 kB 7.0 MB/s eta 0:00:01
# ...
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=f7f0ad2bc940a888efcab776d8c3831d4a7e8fc6bef07955375825b64fc3d179
#   Stored in directory: /root/.cache/pip/wheels/ef/92/e0/956c00decf3091294b8800d9104f6169a1adacfaafd122ed42
# Successfully built et-xmlfile
# ...
# WARNING: You are using pip version 20.2.4; however, version 21.0.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import numpy as np
import requests
import os
from os.path import join,expanduser
import shutil
import tensorflow_hub

pd.set_option('display.max_colwidth',  None)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-4-186effdaa8da> in <module>
#       4 from os.path import join,expanduser
#       5 import shutil
# ----> 6 import tensorflow_hub
#       7
#       8 pd.set_option('display.max_colwidth',  None)
#
# ModuleNotFoundError: No module named 'tensorflow_hub'

# %%
pwd
# Out:
# '/tf'

# %%
df = pd.read_excel(r'/tf/result_asins_1.xlsx', engine='openpyxl')

# %%
df.head()
# Out:
#    Input ASIN        ASIN                           Amazon link UPC List  \
# 0  0615629768  0615629768  https://www.amazon.com/dp/0615629768        -
# 1  147750026X  147750026X  https://www.amazon.com/dp/147750026X        -
# 2  1480258504  1480258504  https://www.amazon.com/dp/1480258504        -
# 3  0988464225  0988464225  https://www.amazon.com/dp/0988464225        -
# 4  0131154028  0131154028  https://www.amazon.com/dp/0131154028        -
#
#         EAN List                          MPN ISBN  \
# 0  9780615629766                            -    -
# 1  9781477500262                            -    -
# 2  9781480258501                            -    -
# 3  9780988464223  black & white illustrations    -
# 4  9780131154025                            -    -
#
#                                                                                   Title  \
# 0                                                                                  2016
# ...

# %%
df = df.replace('-', np.nan)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100011 entries, 0 to 100010
# Data columns (total 19 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Input ASIN           100011 non-null  object
#  1   ASIN                 100000 non-null  object
#  2   Amazon link          100000 non-null  object
#  3   UPC List             6919 non-null    object
#  4   EAN List             92867 non-null   object
#  5   MPN                  31833 non-null   object
#  6   ISBN                 0 non-null       float64
#  7   Title                99147 non-null   object
#  8   Brand                70341 non-null   object
#  9   Dimensions (in)      94336 non-null   object
#  10  Weight (lb)          94336 non-null   float64
#  11  Image link           99064 non-null   object
#  12  Lowest Price (USD)   85015 non-null   float64
#  13  Number of Sellers    87635 non-null   float64
# ...

# %%
df['Image File'] = df['Image link'].str.split('/I/').str[1]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100011 entries, 0 to 100010
# Data columns (total 20 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Input ASIN           100011 non-null  object
#  1   ASIN                 100000 non-null  object
#  2   Amazon link          100000 non-null  object
#  3   UPC List             6919 non-null    object
#  4   EAN List             92867 non-null   object
#  5   MPN                  31833 non-null   object
#  6   ISBN                 0 non-null       float64
#  7   Title                99147 non-null   object
#  8   Brand                70341 non-null   object
#  9   Dimensions (in)      94336 non-null   object
#  10  Weight (lb)          94336 non-null   float64
#  11  Image link           99064 non-null   object
#  12  Lowest Price (USD)   85015 non-null   float64
#  13  Number of Sellers    87635 non-null   float64
# ...

# %%
df = df.dropna(subset=['Image File'])

# %%
df2 = df.iloc[5:9,:]

# %%
df2.head()
# Out:
#    Input ASIN        ASIN                           Amazon link UPC List  \
# 5  1421681463  1421681463  https://www.amazon.com/dp/1421681463      NaN
# 6  0134358716  0134358716  https://www.amazon.com/dp/0134358716      NaN
# 7  0877990522  0877990522  https://www.amazon.com/dp/0877990522      NaN
# 8  B0080ZB6P0  B0080ZB6P0  https://www.amazon.com/dp/B0080ZB6P0      NaN
#
#         EAN List                    MPN  ISBN  \
# 5  9781421681467                    NaN   NaN
# 6  9780134358710                    NaN   NaN
# 7  9780877990529                    NaN   NaN
# 8            NaN  new-20170302-c0051371   NaN
#
#                                                                                                                        Title  \
# 5                                                                             Florida Nature 2012 Square 12X12 Wall Calendar
# ...

# %%
path = r'home/dan/fullstack/result_asins_1.xlsx'
home = r'/home/dan/fullstack'
df = df

#Pass a df, download the images from the urls in the df and put them into a folder
def download_urls(df):
    df = df
    for index, row in df.iterrows():
        folder = 'C:/Users/dan/Downloads/asins'
        ASIN = row['ASIN']
        url = row['Image link']
        file_name = row['Image File']
        r = requests.get(url)
        # Check if the image was retrieved successfully
        if r.status_code == 200:
            if not os.path.exists(folder):
                    os.makedirs(folder)
        with open('{0}/{1}'.format(folder, file_name), 'wb') as f:
                    f.write(r.content)

# %%
download_urls(df)

# %% [markdown]
#     if r.status_code == 200:
#         with open('C:/Users/dan/Downloads/sample.jpg', 'wb') as f:
#             f.write(r.content)
#
#
#
#     ###
#     # Set decode_content value to True, otherwise the downloaded image file's size will be zero.
#         r.raw.decode_content = True
#         # Open a local file with wb ( write binary ) permission.
#         with open(file_name,'wb') as f:
#             shutil.copyfileobj(r.raw, f)
#         print('Image sucessfully Downloaded: ',filename)
#     else:
#         print('Image Couldn\'t be retreived')
#     ###
#
#         ###
#         filepath = join(home, file_name)
#         if not os.path.exists(filepath):
#             os.makedirs(filepath)
#
#         if r.status_code == 200:
#             with open(filepath, "wb") as f:
#                 f.write(r.content)
